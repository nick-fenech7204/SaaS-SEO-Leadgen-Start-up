# %%
import pandas as pd
import re
from urllib.parse import unquote
import os
import time
import random
import numpy as np
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize
import uuid
from datetime import datetime

# %% [markdown]
# * The SerpstatKeywordProcedure.getAdsCompetitors method
# * Performs list of competitors in PPC for the given keyword. The data set is similar to the Competitors report in PPC research of the keywords.

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data = {
    "id": "1",
    "method": "SerpstatKeywordProcedure.getAdsCompetitors",
    "params": {
    "query": "dentist near me",
    "se": "g_us",
    "page": "1",
    "size": "20",
        "sort": {
                "ads": "desc"}
                }
}

api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
df
# Out:
#                               domain  ads  all  common
# 0                       virginia.gov   72  216       1
# 1                         zocdoc.com   68   25       1
# 2                  varinosdental.com   27   27       4
# 3            whitingdentalstudio.com    7    7       3
# 4                      sfldental.com    5   16       2
# 5                       r3dental.com    2    4       1
# 6                    doctoralexa.com    1   27       1
# 7                  lakesidesmile.com    1    1       1
# 8                  slatedentaldc.com    1    1       1
# 9               mysyossetdentist.com    1    3       1
# 10  portorchardcosmeticdentistry.com    1  349       4
# 11                           chp.edu    0    3       1
# 12              manasardentistry.com    0    1       1
# 13           dentistryondanforth.com    0    1       1
