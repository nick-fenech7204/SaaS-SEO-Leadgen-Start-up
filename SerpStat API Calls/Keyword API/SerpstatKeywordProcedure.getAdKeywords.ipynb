# %%
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize

# %% [markdown]
# * The SerpstatKeywordProcedure.getAdKeywords returns paid keywords and ads copies that pop up for the queried keyword in paid search results.
# * The data set is similar to the Keyword research — PPC research — Ads examples report.

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data = {
 "id": "1",
 "method": "SerpstatKeywordProcedure.getAdKeywords",
 "params": {
   "keyword": "dentist",
   "se": "g_us",
   "domains": ["prosites.com","growthplug.com"],
   "filters": {"position_from": 1, "position_to":6},
   "sort" : {"position":"asc"},
   "page": "1",
   "size": "10"
    }
}

api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
df
## Contains Domain Rank
# Out:
#                 keyword  keyword_length        domain         subdomain  \
# 0   dentist seo experts               3  prosites.com   go.prosites.com
# 1  dentist seo services               3  prosites.com  www.prosites.com
# 2           dentist web               2  prosites.com   go.prosites.com
#
#                                                  url  \
# 0  http://go.prosites.com/D-LP-SEO-for-Dentists.html
# 1  https://www.prosites.com/dental-marketing/sear...
# 2         https://go.prosites.com/bundle-retain.html
#
#                                                title  \
# 0          Dental SEO Experts | Attract New Patients
# 1  Find Dental SEO Packages | Increase Brand Awar...
# 2                     Stunning Websites For Dentists
#
#                                                 text  position type  \
# 0  We Handle Your Content And Website Development...         1    3
# 1  We Handle Your Content And Website Development...         1    3
# 2  Professional Website Design — 7,500+ Dentists ...         2    3
#
#         cost  concurrency  found_results  region_queries_count  \
# 0   5.000000            7        4290000                   590
# 1  15.357587           16        5150000                   260
# 2   5.760000           30      178000000                  1600
#
#    region_queries_count_wide  \
# 0                        590
# 1                          0
# 2                          0
#
#                                                types geo_names  difficulty
# 0  [ads_bot, also_asks, local_pack, related_searc...        []           3
# 1   [local_pack, also_asks, related_search, ads_bot]        []           4
# 2                 [ads_top, ads_bot, related_search]        []          18
