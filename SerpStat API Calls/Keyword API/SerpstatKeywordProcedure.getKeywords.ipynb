# %%
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize

# %% [markdown]
# * The SerpstatKeywordProcedure.getKeywords method
# * Shows organic keywords associated with the researched keyword that domains are ranking for in Google`s top-100 results and for every found keyword you’ll see its volume, CPC and level of competition.
# * The data set is similar to the Keyword research — SEO research — Keywords selection report.

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data = {
 "id": "1",
 "method": "SerpstatKeywordProcedure.getKeywords",
 "params": {
   "keyword": "gun sales near me",
   "se": "g_us",
   "filters": {"lang": "en"},
   "sort": {"difficulty": "desc"},
   "page": '1',
   "size": '15'
 }
}

api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
df
# Out:
#                                 keyword  cost  concurrency  found_results  \
# 0             gun safe for sale near me  0.30           40      203000000
# 1            gun safes for sale near me  0.31           31       12800000
# 2                gun safe sales near me  0.29           37       38000000
# 3            stun guns for sale near me  0.00            0        5500000
# 4             stun gun for sale near me  0.00            0        8940000
# 5           tattoo gun for sale near me  0.20           56             95
# 6          tattoo guns for sale near me  0.28           74             78
# 7          gun holster for sale near me  0.31          100       29800000
# 8         gun holsters for sale near me  0.31          100       18500000
# 9           grease gun for sale near me  0.30           27             84
# 10            heat gun for sale near me  0.37           16       77600000
# 11            gun safes on sale near me  0.29           41       11400000
# ...

# %%
lst_of_leag = df['keyword'].to_list()

lst_of_leag
# Out:
# ['downtown legal services',
#  'legal services lawyer',
#  'legal service',
#  'legal aid legal services',
#  'legal service lawyer',
#  'legal-services',
#  'lawyer legal services',
#  'legal services law',
#  'legal services',
#  'legal services legal services',
#  'free legal service near me',
#  'free legal services near me',
#  'praire legal services',
#  'prairie state legal services inc',
#  'prarie legal services',
#  'prairie legal service',
#  'prairie legal services',
#  'praire state legal services',
#  'health care service corporation a mutual legal reserve company',
#  'prarie state legal services',
#  'prarie state legal service',
#  'prairie state legal service',
#  'prairie state legal services',
#  'prairie states legal services',
#  'service legal agreements',
#  'legal referral services',
#  'free legal services',
#  'legal services of indiana',
#  'service legal agreement',
#  'indiana legal services',
#  'legal services indiana',
#  'legal services for free',
# ...
