# %%
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize

# %% [markdown]
# * The SerpstatKeywordProcedure.getKeywordsInfo method
# * Provides you with the keyword overview showing its volume, CPC, level of competition, etc. The data set is similar to the Overview report in Keyword research.

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

lst_of_keys = [
    "Steel Fabrication near me", "Metal Welding Services near me", "Metal Punching near me", 
    "Metal Prototyping near me", "Metal Pressing near me", "Metal Extrusion near me", 
    "Metal Cutting Services near me", "Metal Bending near me", "Metal Assembly near me", 
    "Machined Metal Parts near me", "Laser Cutting Services near me", "Heavy Metal Fabrication near me", 
    "Die Casting near me", "Custom Metal Parts near me"
]


lst_dfs = []

data = {
    "id": "1",
    "method": "SerpstatKeywordProcedure.getKeywordsInfo",
    "params": {
        "keywords": [
    "Steel Fabrication near me", "Metal Welding Services near me", "Metal Punching near me", 
    "Metal Prototyping near me", "Metal Pressing near me", "Metal Extrusion near me", 
    "Metal Cutting Services near me", "Metal Bending near me", "Metal Assembly near me", 
    "Machined Metal Parts near me", "Laser Cutting Services near me", "Heavy Metal Fabrication near me", 
    "Die Casting near me", "Custom Metal Parts near me"
],
        "se": "g_us"
        }
    }


resp = requests.post(api_url, json=data)
if resp.status_code == 200:
    result = resp.json()
    tabular = result['result']['data']


tabular = result['result']['data']
df = pd.json_normalize(tabular)

df.to_clipboard()
df
# Out:
#                           keyword      cost  concurrency  found_results  \
# 0  laser cutting services near me  1.890000           25      219000000
# 1           metal bending near me  2.449979           26       38500000
# 2             die casting near me  2.700000           22      162000000
# 3       steel fabrication near me  2.089999           20       45700000
# 4  metal cutting services near me  1.680000           38      328000000
# 5  metal welding services near me  1.330000           51       42900000
#
#    region_queries_count  region_queries_count_wide  \
# 0                  1300                          0
# 1                   390                          0
# 2                   110                          0
# 3                  8100                          0
# 4                   210                          0
# 5                    20                         20
#
#                                                types geo_names  \
# ...
