# %%
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize
from io import StringIO

# %% [markdown]
# * Method SerpstatKeywordProcedure.exportSuggestions exports to .csv file search suggestions and questions.
# * The data is similar to the report from the section “Keyword research — SEO research — Search suggestions and Search questions”.

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data = {
   "id": 1,
    "method": "SerpstatKeywordProcedure.exportSuggestions",
    "params": {
        "keyword": "legal",
        "se": "g_us",
        "size": 10,
        "page": 1,
        "withQuestions":True,
        "filters": {
            "questions": [
                "is",
            ],
            "keyword_length": 2
        }
    }
}

api_resp = requests.post(api_url, json=data, headers=headers)
data_io = StringIO(api_resp.text)
df = pd.read_csv(data_io)
df
# Out:
#                                   Search suggestions            Question
# 0      what is the legal age for transgender surgery             what,is
# 1   what is the legal age to get transgender surgery             what,is
# 2  what is the legal status of a sole trader's bu...             what,is
# 3  it is said that the sole proprietorship is not...  it,is,is,what,does
# 4                who is the legal heir of ratan tata              who,is
# 5                    what is sex trafficking legally             what,is
# 6  what is the importance of the code of hammurab...             what,is
# 7  what is the significance of the code of hammur...             what,is
# 8  what is the legal length of a knife in new jersey             what,is
# 9                           where is surrogacy legal            where,is
