# %%
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize

# %% [markdown]
# * The SerpstatBacklinksProcedure.getSummaryV2 method gives you general information about link profile:
# * Number of external links, referring IP addresses and subnets, number of referring domains and subdomains, domain authority indicator and types of referring links.
# * The Data set is similar to the Overview report.
#
# * 1) Use SerpstatBacklinksProcedure.getSummaryV2 to get information about the number of inbound links and referring domains;
# * 2) Determine which sites are linking to your competitors to identify potential link opportunities for your client.

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data = {
 "id": "1",
 "method": "SerpstatBacklinksProcedure.getSummaryV2",
 "params": {
     "query" : "prosites.com",
     "searchType": "domain_with_subdomains"
  }
}

api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
df
# Out:
#    sersptat_domain_rank  referring_domains  referring_domains_change  \
# 0                    40               5345                        -9
#
#    redirected_domains  referring_malicious_domains  \
# 0                   0                            0
#
#    referring_malicious_domains_change  referring_ip_addresses  \
# 0                                   0                     238
#
#    referring_ip_addresses_change  referring_subnets  referring_subnets_change  \
# 0                             -2                196                         0
#
#    ...  frame_backlinks  frame_backlinks_change  form_backlinks  \
# 0  ...                3                       0               0
#
#    form_backlinks_change  external_domains  external_domains_change  \
# 0                      0               102                        0
#
#    external_malicious_domains  external_malicious_domains_change  \
# 0                           0                                  0
#
# ...
