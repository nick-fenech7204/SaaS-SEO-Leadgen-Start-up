# %%
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize

# %% [markdown]
# * The getLostOutlinks method gives you a list of lost external links of a site you analyze.
# * The data set is similar to the Lost external links report.
#
# * Use case: with the getLostOutlinks method, check what links your site has lost to find out why they were lost and try to establish these links again.

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data ={
 "id": 1,
 "method": "SerpstatBacklinksProcedure.getLostOutlinks",
 "params": {
     "query": "nike.com",
     "searchType": "domain",
     "sort": "url_from",
     "order": "desc",
     "page": 1,
     "size": 2,
     "linkPerDomain": 1,
     "complexFilter": [
            [
                {
                    "field": "url_from",
                    "compareType": "notContains",
                    "value": [
                        "7654765"
                    ]
                },
                {
                    "field": "link_nofollow",
                    "compareType": "contains",
                    "value": [
                        "follow",
                        "nofollow",
                        "ugc",
                        "sponsored"
                    ]
                },
                {
                    "field": "anchor",
                    "compareType": "notContains",
                    "value": [
                        "лопспрол"
                    ]
                },
                {
                    "field": "check",
                    "compareType": "lte",
                    "value": [
                        "1.1.2030"
                    ]
                },
                {
                    "field": "links_external",
                    "compareType": "between",
                    "value": [
                        "1",
                        "500"
                    ]
                }
            ],
            [
                {
                    "field": "links_external",
                    "compareType": "lte",
                    "value": [
                        "800"
                    ]
                }
            ]
        ]
  }
}

api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
df
# Out:
#                                             url_from  \
# 0  https://www.nike.com/my/w/mens-air-max-shoes-a...
# 1  https://www.nike.com/my/w/mens-air-force-1-sho...
#
#                                               url_to link_nofollow link_type  \
# 0  https://www.eshopworld.com/terms-and-condition...        follow      href
# 1  https://www.eshopworld.com/terms-and-condition...        follow      href
#
#    links_external      link_text  first_seen         last_visited  \
# 0              22  Terms of Sale  2022-11-03  2024-08-20 11:02:51
# 1              22  Terms of Sale  2022-11-03  2024-08-20 11:03:05
#
#               date_del
# 0  2024-08-20 11:02:51
# 1  2024-08-20 11:03:05
