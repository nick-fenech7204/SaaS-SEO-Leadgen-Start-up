# %%
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize

# %% [markdown]
# * The SerpstatBacklinksProcedure.getTopPages method gives you a list of leading pages of the analyzed site by the number of backlinks with referring pages, domains and IPs.
#
# * Use case: With the SerpstatBacklinksProcedure.getTopPages method, check how many backlinks have different pages of the site to analyze it and optimize future promotion.

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data ={
 "id": 1,
 "method": "SerpstatBacklinksProcedure.getTopPages",
 "params": {
     "query": "prosites.com",
     "searchType": "domain",
     "page": 1,
     "sort": "ips",
     "order": "desc",
     "complexFilter": [
           [
                {
                    "field": "count",
                    "compareType": "gte",
                    "value": [
                        "1"
                    ]
                },
                {
                    "field": "ips",
                    "compareType": "gte",
                    "value": [
                        "1"
                    ]
                }
            ]
        ]
  }
}


api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
df
# Out:
#                                                   url  ref_pages  ref_domains  \
# 0                                                   /     127752          959
# 1                                                   /     371655         3033
# 2                                                          11738          173
# 3                                /terms-of-use/video/       4449         3699
# 4                                                             98           81
# ..                                                ...        ...          ...
# 95  /dental-marketing-wisdom/seo/authority/backlin...         10            1
# 96  /dental-marketing/dental-facebook-ads-and-mark...          1            1
# 97                /dental-marketing/ppc-for-dentists/          1            1
# 98                  /dental-marketing/video-marketing          1            1
# 99  /get-started-with-prosites/?_bg=21744813544&_b...          1            1
#
# ...
