# %%
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize

# %% [markdown]
# * The SerpstatBacklinksProcedure.getOutDomains method gives you a list of the domains that are linked to the analyzed site.
#
# * The data set is similar to the External domains report.
#
#
# * Use case: with the SerpstatBacklinksProcedure.getOutDomains method, check what domains are linked to a competitor's domain and link your own domain to these domains.

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data ={
 "id": 1,
 "method": "SerpstatBacklinksProcedure.getOutDomains",
 "params": {
     "query": "prosites.com",
     "searchType": "domain",
     "sort": "domain_links",
     "order": "desc",
     "page": 1,
     "complexFilter": [
            [
                {
                    "field": "domain_to",
                    "compareType": "contains",
                    "value": [
                        ".com"
                    ]
                },
                {
                    "field": "domain_rank",
                    "compareType": "gte",
                    "value": [
                        "1"
                    ]
                },
                {
                    "field": "domain_links",
                    "compareType": "gte",
                    "value": [
                        "1"
                    ]
                },
                 {
                    "additional_filters": "only_subdomains"
                }
            ]
        ]
  }
}

api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
df
# Out:
#                            domain_to  domain_links  domain_rank
# 0                  blog.prosites.com           310            0
# 1                engine.prosites.com            12            0
# 2                   w.soundcloud.com             9            0
# 3                    go.prosites.com             5            0
# 4                 adwords.google.com             1            0
# 5               business.twitter.com             1            0
# 6                 help.instagram.com             1            0
# 7   investors.synchronyfinancial.com             1            0
# 8       marketingplatform.google.com             1            0
# 9                    plus.google.com             1            0
# 10                privacy.truste.com             1            0
# 11     prosites59059.td.prosites.com             1            0
# 12                 search.google.com             1            0
# 13      secure.bingads.microsoft.com             1            0
# ...
