# %%
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize

# %% [markdown]
# * SerpstatBacklinksProcedure.getDistributionSDR method returns an array containing objects with SDR value ranges and the number of domains that are included in these ranges.
# * The data set is similar to the graph SDR distribution in the Overview report.

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data = {
 "id": "1",
 "method": "SerpstatBacklinksProcedure.getDistributionSDR",
 "params": {
     "query" : "prosites.com",
     "searchType": "domain_with_subdomains"
  }
}

api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
df
# Out:
#    sdr_range  domains
# 0          0      730
# 1      1 - 9     1496
# 2    10 - 19     2701
# 3    20 - 29      353
# 4    30 - 39       81
# 5    40 - 49       55
# 6    50 - 59       18
# 7    60 - 69        3
# 8    70 - 79        1
# 9    80 - 89        0
# 10  90 - 100        0
