# %% [markdown]
# ## [SerpstatDomainProcedure.getTopUrls Method](https://serpstat.com/api/keyword-top-pages/)

# %%
import pandas as pd
import re
from urllib.parse import unquote
import os
import time
import random
import numpy as np
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize
import uuid
from datetime import datetime

# %% [markdown]
# ### Key Features
#
# * Retrieve Top Ranking URLs for a Domain: The method identifies the URLs from a domain that have the best rankings for various search queries.
#
# * Analyze High-Performance Pages: It highlights which pages are driving the most traffic or have the highest visibility, offering valuable insights into the site's content performance.
#
# * Support SEO Strategy and Content Optimization: By understanding which URLs are top performers, website owners can adjust their SEO strategies, focusing efforts on optimizing these pages or creating similar content.
#
# * Also, it shows the number of keywords from Google top-100 for each URL, approximate traffic of the page and Facebook shares. The data set is similar to the Top pages report of the Domain Analysis.

# %% [markdown]
# | Column             | Description                                                                                           |
# |--------------------|-------------------------------------------------------------------------------------------------------|
# | url                | The specific URL of the page being analyzed. This represents the webpage from the domain.             |
# | organic_keywords   | The number of organic keywords associated with the URL, indicating how many keywords it ranks for.    |
# | facebook_shares    | The number of times the URL has been shared on Facebook, indicating its social media engagement.      |
# | potencial_traff    | The potential traffic the URL could drive based on its rankings and visibility.                       |

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data = {
    "id": "1",
    "method": "SerpstatDomainProcedure.getTopUrls",
    "params": {
    "domain": "nike.com",
    "se": "g_us",
    "sort": {"organic_keywords":"desc"},
    "page": "1",
    "size": "50"}
}

api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
df
# Out:
#                                                   url  organic_keywords  \
# 0                              https://jobs.nike.com/             98967
# 1                               https://www.nike.com/             38131
# 2      https://www.nike.com/w/womens-shoes-5e1x6zy7ok             28159
# 3                         https://www.nike.com/retail             27189
# 4    https://www.nike.com/w/jordan-1-shoes-4fokyzy7ok             27123
# 5                   https://www.nike.com/w/shoes-y7ok             26365
# 6         https://www.nike.com/w/mens-shoes-nik1zy7ok             25797
# 7      https://www.nike.com/w/jordan-shoes-37eefzy7ok             24404
# 8       https://www.nike.com/w/kids-jordan-37eefzv4dh             22992
# 9                 https://www.nike.com/w/jordan-37eef             22613
# 10                        https://www.nike.com/jordan             21424
# 11        https://www.nike.com/size-fit/mens-footwear             21089
# ...
