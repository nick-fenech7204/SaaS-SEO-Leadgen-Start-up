# %% [markdown]
# ## [SerpstatDomainProcedure.getRegionsCount Method](https://serpstat.com/api/sorting-the-domain-by-keywords/)

# %%
import pandas as pd
import re
from urllib.parse import unquote
import os
import time
import random
import numpy as np
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize
import uuid
from datetime import datetime

# %% [markdown]
# ## Key Features
#
# * Retrieve Number of Regions for a Domain: The method calculates how many distinct regions the domain is ranking in, offering insights into its regional SEO footprint.
#
# * Analyze Domain's Regional Presence: The method helps you determine the geographic distribution of a domain's rankings, showing its international or localized SEO performance.
#
# * Support SEO and Localization Strategies: Understanding which regions the domain performs well in allows SEO teams to tailor content or campaigns to those areas or focus on regions where performance is low.
#
# * Returns an array with information about the number of keys per domain in Serpstat databases. Databases with a number of keys equal to zero are not shown in the response.

# %% [markdown]
# | Column           | Description                                                                                           |
# |------------------|-------------------------------------------------------------------------------------------------------|
# | country_name_en  | The name of the country in English where the domain is ranking.                                         |
# | db_name          | The database name or identifier used for the country/region.                                           |
# | domain           | The domain that is being analyzed (e.g., google.com, google.co.uk).                                      |
# | keywords_count   | The number of keywords the domain ranks for in that specific country or region.                        |

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data = {
    "id": 1,
    "method": "SerpstatDomainProcedure.getRegionsCount",
    "params": {
        "domain": "prosites.com",
        "db_name": 'g_us',
        "country_name_en": 'United States'
    }
}
api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
## Careful with this takes alot of credits
df
# Out:
#                country_name_en db_name         domain  keywords_count
# 0                United States    g_us     google.com           34764
# 1               United Kingdom    g_uk   google.co.uk            5613
# 2                       Canada    g_ca      google.ca            4435
# 3                    Australia    g_au  google.com.au            1610
# 4                        Spain    g_es      google.es            1435
# ..                         ...     ...            ...             ...
# 196  Saint Pierre and Miquelon    g_pm     google.com               1
# 197                      Nauru    g_nr      google.nr               1
# 198                      Niger    g_ne      google.ne               1
# 199                       Chad    g_td      google.td               1
# 200                     Guinea    g_gn     google.com               1
#
# [201 rows x 4 columns]
