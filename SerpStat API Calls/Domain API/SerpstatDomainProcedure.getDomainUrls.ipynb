# %% [markdown]
# ## [SerpstatDomainProcedure.getDomainUrls Method](https://serpstat.com/api/586-list-of-domain-urls-v4-serpstatdomainproceduregetdomainurls/)

# %%
import pandas as pd
import re
from urllib.parse import unquote
import os
import time
import random
import numpy as np
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize
import uuid
from datetime import datetime

# %% [markdown]
# ### Key Features
#
# * The data set is similar to the Top pages report of the Domain Analysis, excluding the information about traffic and number of Facebook shares.
#
# * Retrieve URLs for a Domain: This method pulls the list of URLs that belong to a domain and are relevant to SEO or search performance.
#
# * Analyze Domain's Ranking URLs: It helps identify which pages (URLs) from a domain appear in search results, helping to determine the effectiveness of content strategies.
#
# * Support SEO and Traffic Strategy: By providing detailed data on the domain’s URLs, the method supports a deeper analysis of a site's SEO performance, aiding in optimization and targeted traffic strategies.

# %% [markdown]
# | Column   | Description                                                                                   |
# |----------|-----------------------------------------------------------------------------------------------|
# | url      | The specific URL of the page within the domain being analyzed. It represents the webpage.     |
# | keywords | The number of unique keywords associated with that URL. This indicates how many keywords the page ranks for in search results. |

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data = {
 "id": "1",
 "method": "SerpstatDomainProcedure.getDomainUrls",
 "params": {
   "domain": "prosites.com",
   "se": "g_us",
   "sort": {"keywords": "desc"},
   "page": "1",
   "size": "20"
 }
}
api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
## Need to get the total amount from the end of json
df
# Out:
#                                                   url  keywords
# 0   https://c3-preview.prosites.com/264612/wy/docs...      2610
# 1   https://c3-preview.prosites.com/241033/wy/docs...      1019
# 2   https://c3-preview.prosites.com/264612/wy/docs...       907
# 3   https://c1-preview.prosites.com/63284/wy/docs/...       282
# 4   https://c2-preview.prosites.com/211192/wy/docs...       257
# 5   http://c3-preview.prosites.com/264612/wy/docs/...       248
# 6                           https://www.prosites.com/       216
# 7   https://www.prosites.com/website-design/dental...       177
# 8   https://c3-preview.prosites.com/241033/wy/docs...       167
# 9   https://c3-preview.prosites.com/241033/wy/docs...       152
# 10  https://c3-preview.prosites.com/277880/wy/docs...       147
# 11  https://c3-preview.prosites.com/237851/wy/docs...       131
# 12  https://c1-preview.prosites.com/64345/wy/docs/...       130
# 13                         https://mail.prosites.com/       123
# ...
