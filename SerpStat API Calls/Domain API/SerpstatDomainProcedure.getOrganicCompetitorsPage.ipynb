# %% [markdown]
# ## [SerpstatDomainProcedure.getOrganicCompetitorsPage Method](https://serpstat.com/api/domain-competitors-in-organic-search-results/)

# %%
import pandas as pd
import re
from urllib.parse import unquote
import os
import time
import random
import numpy as np
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize
import uuid
from datetime import datetime

# %% [markdown]
# ## Key Features
#
# * Brings in the list of domain competitors in top 20 Google search results. The data set is similar to the Competitors report of the domain.
#
# * Identify Organic Competitors for a Domain: This method helps discover the websites that rank for the same keywords in search results, providing insight into the competitive landscape.
#
# * Analyze Competitor Pages: By showing which pages from competing domains are ranking, it aids in understanding what content or SEO strategies are working for competitors.
#
# * Support SEO Strategy and Competitive Analysis: By identifying organic competitors and their ranking pages, SEO professionals can adapt their strategies to stay competitive in search rankings.

# %% [markdown]
# | Column                      | Description                                                                                           |
# |-----------------------------|-------------------------------------------------------------------------------------------------------|
# | domain                      | The primary domain being analyzed.                                                                     |
# | favicon                     | The URL of the favicon associated with the domain. This is typically an image representing the domain. |
# | missing                     | Indicates if there is a missing value (0 typically means no missing value).                           |
# | relevance                   | The relevance score, indicating how relevant the domain or page is for the specific analysis.          |
# | all.currentValue            | The current value for all collected data points (could refer to total metrics for the domain).         |
# | all.dynamicValue            | The dynamic value for the data, showing how much this metric changes over time.                        |
# | common.currentValue         | The current value of common data (likely reflecting a subset of data that applies to common features). |
# | common.dynamicValue         | The dynamic value of common data, showing changes or variations in the common features over time.      |
# | visibility.currentValue     | The current value related to the visibility of the domain or page (e.g., search engine visibility).    |
# | visibility.dynamicValue     | The dynamic value showing how visibility changes over time.                                            |

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data = {
    "id": 1,
    "method": "SerpstatDomainProcedure.getOrganicCompetitorsPage",
    "params": {
    "domain": "prosites.com",
    "se": "g_us",
    "sort": {"relevance":"desc"},
    "page": "1",
    "size": "20"}
}

api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
df
# Out:
#                      domain  \
# 0              prosites.com
# 1   c3-preview.prosites.com
# 2   c1-preview.prosites.com
# 3   c2-preview.prosites.com
# 4      www.ncbi.nlm.nih.gov
# 5   pubmed.ncbi.nlm.nih.gov
# 6    aegisdentalnetwork.com
# 7       dentaleconomics.com
# 8           dentistryiq.com
# 9        dentistrytoday.com
# 10           transitapp.com
# 11        dentalinsider.com
# 12            njtransit.com
# 13               panynj.gov
# 14                  ada.org
# 15     findadentist.ada.org
# 16           carecredit.com
# 17              ratemds.com
# 18             caredash.com
# 19          findatopdoc.com
#
#                                               favicon  missing  relevance  \
# 0   https://www.google.com/s2/favicons?domain=pros...        0     100.00
# 1   https://www.google.com/s2/favicons?domain=c3-p...        0     100.00
# 2   https://www.google.com/s2/favicons?domain=c1-p...        0     100.00
# ...
