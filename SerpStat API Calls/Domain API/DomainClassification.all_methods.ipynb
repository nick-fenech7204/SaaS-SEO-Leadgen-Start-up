# %%
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize

# %%
path = r"C:\Users\nickj\OneDrive\Desktop\Xoinx\Xoinx Value Prospecting Firms\develomark_serp_data_12.16.24.xlsx"

riseoak = pd.read_excel(path, sheet_name='big_players_out')

lst_of_domains = riseoak['domains'].drop_duplicates().to_list()

lst_of_domains = lst_of_domains
len(lst_of_domains)
# Out:
# 186

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data = {
    "method": "DomainClassification.addTask",
    "id": 1,
    "params": {
        "domains": lst_of_domains
    }
}

api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sending_domains_id = json_response['result']['task_id']

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data = {
    "method": "DomainClassification.getTask",
    "id": 1,
    "params": {
        "task_id": sending_domains_id
    }
}

api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
pd.options.display.max_colwidth=9999
df.to_clipboard()
df
# Out:
#                   domain  \
# 0           prototek.com
# 1         cammmetals.com
# 2    bonnellaluminum.com
# 3            paceind.com
# 4          halseymfg.com
# ..                   ...
# 181    yankeecasting.com
# 182     fablabelpaso.org
# 183    silverhawkfab.com
# 184  reynoldswelding.com
# 185        metal-ind.com
#
#                                                                                                                                                                                                                                                                                                                                                                     categories_names  \
# 0                                                                                                                                                                                [/Business & Industrial/Manufacturing/Other, /Computers & Electronics/CAD & CAM, /Computers & Electronics/Computer Hardware/Computer Peripherals, /Arts & Entertainment/Visual Art & Design/Design]
# 1                                                                                                                                                 [/Business & Industrial/Manufacturing/Other, /Business & Industrial/Metals & Mining/Other, /Business & Industrial/Industrial Materials & Equipment/Other, /Business & Industrial/Industrial Materials & Equipment/Heavy Machinery]
# 2                                                                                                                                         [/Business & Industrial/Metals & Mining/Other, /Business & Industrial/Manufacturing/Other, /Business & Industrial/Construction & Maintenance/Building Materials & Supplies, /Business & Industrial/Industrial Materials & Equipment/Other]
# 3                                                                                                               [/Business & Industrial/Manufacturing/Other, /Business & Industrial/