# %%
from datetime import datetime
import pandas as pd
import requests
from pandas import json_normalize

# %% [markdown]
# * The SerpstatUrlProcedure.getUrlKeywords method returns a list of keywords for which the specified URL ranks in the top-100 Google and top-50 Bing search results.
# * It provides insights into the organic search performance of a page and is ideal for keyword research, content optimization, and competitor analysis.
# * The data set is similar to the URL analysis — SEO research — Keywords report.

# %%
api_token = '185b0a40fdd3abccb33f353c8e3e2918'                                                         
api_url_pattern = 'https://api.serpstat.com/v{version}?token={token}'
api_url = api_url_pattern.format(version=4, token=api_token)

headers = {
    "Content-Type": "application/json",
    "X-Api-Key": f"{api_token}",
}

data = {
    "id": "1",
    "method": "SerpstatUrlProcedure.getUrlKeywords",
    "params": {
        "se": "g_us",
        "url": "https://www.prosites.com/dental-marketing/",
        "filters": {"cost_from": 1, "cost_to": 1000},
        "sort": {"position": "asc"},
        "page": "1",
        "size": "10"
    }
}

api_resp = requests.post(api_url, json=data, headers=headers)
json_response = api_resp.json()
sliced_json = json_response['result']['data']
df = pd.json_normalize(sliced_json)
df
## Contains Domain Rank
# Out:
#          domain         subdomain                             keyword  \
# 0  prosites.com  www.prosites.com          dental marketing solutions
# 1  prosites.com  www.prosites.com           dental marketing solution
# 2  prosites.com  www.prosites.com     d e n t a l marketing solutions
# 3  prosites.com  www.prosites.com     marketing services for dentists
# 4  prosites.com  www.prosites.com         dental marketing california
# 5  prosites.com  www.prosites.com            dental marketing service
# 6  prosites.com  www.prosites.com             dental marketing expert
# 7  prosites.com  www.prosites.com             dental marketing online
# 8  prosites.com  www.prosites.com  dental practice marketing strategy
# 9  prosites.com  www.prosites.com         dentist marketing solutions
#
#    keyword_length                                         url  position  \
# 0               3  https://www.prosites.com/dental-marketing/         3
# ...
